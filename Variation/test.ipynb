# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
#       <iframe id="tensorboard-frame-92b61c338ce4c4cf" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-92b61c338ce4c4cf");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !python -m safe_explorer.main --main_trainer_task ballnd
# Out:
#           _________       _____        ___________              .__
#          /   _____/____ _/ ____\____   \_   _____/__  _________ |  |   ___________   ___________
# 2021-12-15 18:44:28.107512: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-12-15 18:44:28.107578: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#          \_____  \__  \   __\/ __ \   |    __)_\  \/  /\____ \|  |  /  _ \_  __ \_/ __ \_  __ \
#          /        \/ __ \|  | \  ___/   |        \>    < |  |_> >  |_(  <_> )  | \/\  ___/|  | \/
#         /_______  (____  /__|  \___  > /_______  /__/\_ \|   __/|____/\____/|__|    \___  >__|
#                 \/     \/          \/          \/      \/|__|                           \/
#
# ============================================================
# Initialized SafeExplorer with config:
# ------------------------------------------------------------
# Safe Explorer:
#     env:
#         spaceship:
#             length: 2.5
#             margin: 0.2
#             agent_slack: 0.05
#             frequency_ratio: 0.1
#             target_noise_std: 0.05
#             target_radius: 0.05
#             corridor_episode_length: 15
#             arena_episode_length: 45
#             enable_reward_shaping: False
#             is_arena: True
#             reward_shaping_slack: 0.1
#         ballnd:
#             n: 1
#             target_margin: 0.2
#             agent_slack: 0.05
#             episode_length: 30
#             frequency_ratio: 0.1
#             respawn_interval: 0.5
#             target_noise_std: 0.05
#             enable_reward_shaping: False
#             reward_shaping_slack: 0.1
#     ddpg:
#         actor:
#             layers: [128, 64]
#             init_bound: 0.003
#         critic1:
#             layers: [64, 128, 32]
#             init_bound: 0.003
#         critic2:
#             layers: [64, 128, 32]
#             init_bound: 0.003
#         trainer:
#             epochs: 100
#             steps_per_epoch: 6000
#             evaluation_steps: 1500
#             batch_size: 256
#             max_episode_length: 300
#             replay_buffer_size: 1000000
#             discount_factor: 0.99
#             polyak: 0.995
#             actor_lr: 0.001
#             critic1_lr: 0.001
#             critic2_lr: 0.001
#             start_steps: 500
#             action_noise_range: 0.01
#             use_gpu: False
#             reward_scale: 1
#             max_updates_per_episode: 10
#             min_buffer_fill: 2000
#     safety_layer:
#         constraint_model:
#             layers: [10, 10]
#             init_bound: 0.003
#         trainer:
#             batch_size: 256
#             lr: 0.0001
#             max_episode_length: 300
#             steps_per_epoch: 6000
#             epochs: 25
#             evaluation_steps: 1500
#             replay_buffer_size: 1000000
#             use_gpu: False
#     main:
#         trainer:
#             seed: 0
#             task: ballnd
#             use_safety_layer: False
# ============================================================
# ==========================================================
# Initializing DDPG training...
# ----------------------------------------------------------
# Start time: 2021-12-15 18:44:31.504191
# ==========================================================
# Finished epoch 1.0. Running validation ...
# Validation completed:
# Number of episodes: 7
# Average episode length: 212.0
# Average reward: -0.5913519871950286
# Average action magnitude: 0.023614397272467613
# ----------------------------------------------------------
# Finished epoch 2.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: -3.023669501943737
# Average action magnitude: 0.07376523315906525
# ----------------------------------------------------------
# Finished epoch 3.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.031159919583494
# Average action magnitude: 0.48061108589172363
# ----------------------------------------------------------
# Finished epoch 4.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.627593873180423
# Average action magnitude: 0.6593648195266724
# ----------------------------------------------------------
# Finished epoch 5.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 23.338365263333966
# Average action magnitude: 0.7953872680664062
# ----------------------------------------------------------
# Finished epoch 6.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.715220055073196
# Average action magnitude: 0.8646011352539062
# ----------------------------------------------------------
# Finished epoch 7.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 23.22594436718216
# Average action magnitude: 0.8986523747444153
# ----------------------------------------------------------
# Finished epoch 8.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.891845024668587
# Average action magnitude: 0.9201876521110535
# ----------------------------------------------------------
# Finished epoch 9.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 23.629633214772284
# Average action magnitude: 0.9424484968185425
# ----------------------------------------------------------
# Finished epoch 10.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.475764953822278
# Average action magnitude: 0.940456748008728
# ----------------------------------------------------------
# Finished epoch 11.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.587212379942507
# Average action magnitude: 0.9499027132987976
# ----------------------------------------------------------
# Finished epoch 12.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.325965850783138
# Average action magnitude: 0.9540722966194153
# ----------------------------------------------------------
# Finished epoch 13.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 19.9007341092374
# Average action magnitude: 0.9627803564071655
# ----------------------------------------------------------
# Finished epoch 14.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.30856390931755
# Average action magnitude: 0.9578803181648254
# ----------------------------------------------------------
# Finished epoch 15.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.230056411699543
# Average action magnitude: 0.9700380563735962
# ----------------------------------------------------------
# Finished epoch 16.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.136152326866146
# Average action magnitude: 0.9648502469062805
# ----------------------------------------------------------
# Finished epoch 17.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.026555994244063
# Average action magnitude: 0.9703582525253296
# ----------------------------------------------------------
# Finished epoch 18.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.984076109592856
# Average action magnitude: 0.9771751165390015
# ----------------------------------------------------------
# Finished epoch 19.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.116990539573568
# Average action magnitude: 0.9722931981086731
# ----------------------------------------------------------
# Finished epoch 20.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.000163845679772
# Average action magnitude: 0.9725488424301147
# ----------------------------------------------------------
# Finished epoch 21.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 18.59238286313304
# Average action magnitude: 0.9736980199813843
# ----------------------------------------------------------
# Finished epoch 22.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.37728286358528
# Average action magnitude: 0.968330979347229
# ----------------------------------------------------------
# Finished epoch 23.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 18.287592286012284
# Average action magnitude: 0.9801770448684692
# ----------------------------------------------------------
# Finished epoch 24.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.39344156198096
# Average action magnitude: 0.9812750816345215
# ----------------------------------------------------------
# Finished epoch 25.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 19.760607587997633
# Average action magnitude: 0.9764072299003601
# ----------------------------------------------------------
# Finished epoch 26.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.221126358783206
# Average action magnitude: 0.9808986783027649
# ----------------------------------------------------------
# Finished epoch 27.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.69945378036285
# Average action magnitude: 0.9811689257621765
# ----------------------------------------------------------
# Finished epoch 28.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.35966662217257
# Average action magnitude: 0.9831075668334961
# ----------------------------------------------------------
# Finished epoch 29.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.613747790947034
# Average action magnitude: 0.9805957078933716
# ----------------------------------------------------------
# Finished epoch 30.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.894799598601505
# Average action magnitude: 0.9826383590698242
# ----------------------------------------------------------
# Finished epoch 31.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.746425285037066
# Average action magnitude: 0.9820232391357422
# ----------------------------------------------------------
# Finished epoch 32.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 23.074570757858552
# Average action magnitude: 0.9845296144485474
# ----------------------------------------------------------
# Finished epoch 33.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.641296223848673
# Average action magnitude: 0.9807573556900024
# ----------------------------------------------------------
# Finished epoch 34.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.40131840255625
# Average action magnitude: 0.9847666025161743
# ----------------------------------------------------------
# Finished epoch 35.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.71366606349031
# Average action magnitude: 0.9826393127441406
# ----------------------------------------------------------
# Finished epoch 36.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.307601489032017
# Average action magnitude: 0.9877344965934753
# ----------------------------------------------------------
# Finished epoch 37.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.874702726150428
# Average action magnitude: 0.9839032292366028
# ----------------------------------------------------------
# Finished epoch 38.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 23.628884481552404
# Average action magnitude: 0.9848600625991821
# ----------------------------------------------------------
# Finished epoch 39.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 19.841141699464767
# Average action magnitude: 0.9886037707328796
# ----------------------------------------------------------
# Finished epoch 40.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward:
0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.500882189607903
# Average action magnitude: 0.9943164587020874
# ----------------------------------------------------------
# Finished epoch 74.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.362017330431776
# Average action magnitude: 0.9919255971908569
# ----------------------------------------------------------
# Finished epoch 75.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.13038908353781
# Average action magnitude: 0.9931434392929077
# ----------------------------------------------------------
# Finished epoch 76.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.744874030075845
# Average action magnitude: 0.9956628084182739
# ----------------------------------------------------------
# Finished epoch 77.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.42064464361956
# Average action magnitude: 0.9944243431091309
# ----------------------------------------------------------
# Finished epoch 78.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.45769908756716
# Average action magnitude: 0.9924847483634949
# ----------------------------------------------------------
# Finished epoch 79.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.30601995724517
# Average action magnitude: 0.9924624562263489
# ----------------------------------------------------------
# Finished epoch 80.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.93682693758361
# Average action magnitude: 0.9901854395866394
# ----------------------------------------------------------
# Finished epoch 81.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.44479666060862
# Average action magnitude: 0.9903729557991028
# ----------------------------------------------------------
# Finished epoch 82.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 23.462405354138564
# Average action magnitude: 0.994841456413269
# ----------------------------------------------------------
# Finished epoch 83.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.498864949084467
# Average action magnitude: 0.9925198554992676
# ----------------------------------------------------------
# Finished epoch 84.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.19614964634812
# Average action magnitude: 0.9920161962509155
# ----------------------------------------------------------
# Finished epoch 85.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.749337390393105
# Average action magnitude: 0.9919247627258301
# ----------------------------------------------------------
# Finished epoch 86.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.33809149295135
# Average action magnitude: 0.9925004839897156
# ----------------------------------------------------------
# Finished epoch 87.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.12988114416853
# Average action magnitude: 0.9954324960708618
# ----------------------------------------------------------
# Finished epoch 88.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.501177449519606
# Average action magnitude: 0.9950803518295288
# ----------------------------------------------------------
# Finished epoch 89.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.921331404525965
# Average action magnitude: 0.9931769371032715
# ----------------------------------------------------------
# Finished epoch 90.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.175900711192032
# Average action magnitude: 0.9903624653816223
# ----------------------------------------------------------
# Finished epoch 91.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.718556602916188
# Average action magnitude: 0.9938287734985352
# ----------------------------------------------------------
# Finished epoch 92.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.584528052454925
# Average action magnitude: 0.9940474629402161
# ----------------------------------------------------------
# Finished epoch 93.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.9197145712518
# Average action magnitude: 0.9940757751464844
# ----------------------------------------------------------
# Finished epoch 94.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.898291622060068
# Average action magnitude: 0.9936538934707642
# ----------------------------------------------------------
# Finished epoch 95.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.70864274225371
# Average action magnitude: 0.9934965968132019
# ----------------------------------------------------------
# Finished epoch 96.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.016699426687403
# Average action magnitude: 0.9942363500595093
# ----------------------------------------------------------
# Finished epoch 97.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 19.755178632046295
# Average action magnitude: 0.9918450117111206
# ----------------------------------------------------------
# Finished epoch 98.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.325376024850083
# Average action magnitude: 0.9944931268692017
# ----------------------------------------------------------
# Finished epoch 99.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.326149751443396
# Average action magnitude: 0.9925225973129272
# ----------------------------------------------------------
# ==========================================================
# Finished DDPG training. Time spent: 6872.0 secs
# ==========================================================

# %%
# !python -m safe_explorer.main --main_trainer_task ballnd
# Out:
#           _________       _____        ___________              .__
#          /   _____/____ _/ ____\____   \_   _____/__  _________ |  |   ___________   ___________
#          \_____  \__  \   __\/ __ \   |    __)_\  \/  /\____ \|  |  /  _ \_  __ \_/ __ \_  __ \
#          /        \/ __ \|  | \  ___/   |        \>    < |  |_> >  |_(  <_> )  | \/\  ___/|  | \/
#         /_______  (____  /__|  \___  > /_______  /__/\_ \|   __/|____/\____/|__|    \___  >__|
#                 \/     \/          \/          \/      \/|__|                           \/
#
# ============================================================
# Initialized SafeExplorer with config:
# ------------------------------------------------------------
# Safe Explorer:
# 2021-12-15 21:04:43.253734: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-12-15 21:04:43.253851: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#     env:
#         spaceship:
#             length: 2.5
#             margin: 0.2
#             agent_slack: 0.05
#             frequency_ratio: 0.1
#             target_noise_std: 0.05
#             target_radius: 0.05
#             corridor_episode_length: 15
#             arena_episode_length: 45
#             enable_reward_shaping: False
#             is_arena: True
#             reward_shaping_slack: 0.1
#         ballnd:
#             n: 1
#             target_margin: 0.2
#             agent_slack: 0.05
#             episode_length: 30
#             frequency_ratio: 0.1
#             respawn_interval: 0.5
#             target_noise_std: 0.05
#             enable_reward_shaping: True
#             reward_shaping_slack: 0.1
#     ddpg:
#         actor:
#             layers: [128, 64]
#             init_bound: 0.003
#         critic1:
#             layers: [64, 128, 32]
#             init_bound: 0.003
#         critic2:
#             layers: [64, 128, 32]
#             init_bound: 0.003
#         trainer:
#             epochs: 100
#             steps_per_epoch: 6000
#             evaluation_steps: 1500
#             batch_size: 256
#             max_episode_length: 300
#             replay_buffer_size: 1000000
#             discount_factor: 0.99
#             polyak: 0.995
#             actor_lr: 0.001
#             critic1_lr: 0.001
#             critic2_lr: 0.001
#             start_steps: 500
#             action_noise_range: 0.01
#             use_gpu: False
#             reward_scale: 1
#             max_updates_per_episode: 10
#             min_buffer_fill: 2000
#     safety_layer:
#         constraint_model:
#             layers: [10, 10]
#             init_bound: 0.003
#         trainer:
#             batch_size: 256
#             lr: 0.0001
#             max_episode_length: 300
#             steps_per_epoch: 6000
#             epochs: 25
#             evaluation_steps: 1500
#             replay_buffer_size: 1000000
#             use_gpu: False
#     main:
#         trainer:
#             seed: 0
#             task: ballnd
#             use_safety_layer: False
# ============================================================
# ==========================================================
# Initializing DDPG training...
# ----------------------------------------------------------
# Start time: 2021-12-15 21:04:58.600958
# ==========================================================
# Finished epoch 1.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: -0.0774098710016237
# Average action magnitude: 0.004470820538699627
# ----------------------------------------------------------
# Finished epoch 2.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 0.6496123695436997
# Average action magnitude: 0.01721859909594059
# ----------------------------------------------------------
# Finished epoch 3.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: -7.288406652087241
# Average action magnitude: 0.057838618755340576
# ----------------------------------------------------------
# Finished epoch 4.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 7.340810146615783
# Average action magnitude: 0.10241658985614777
# ----------------------------------------------------------
# Finished epoch 5.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 7.99737257699856
# Average action magnitude: 0.24543336033821106
# ----------------------------------------------------------
# Finished epoch 6.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 14.775185057782505
# Average action magnitude: 0.6079373359680176
# ----------------------------------------------------------
# Finished epoch 7.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.39423533565198
# Average action magnitude: 0.7972776889801025
# ----------------------------------------------------------
# Finished epoch 8.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.126581098991075
# Average action magnitude: 0.8477712869644165
# ----------------------------------------------------------
# Finished epoch 9.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 22.92043178758248
# Average action magnitude: 0.8908214569091797
# ----------------------------------------------------------
# Finished epoch 10.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.26104468398666
# Average action magnitude: 0.9011265635490417
# ----------------------------------------------------------
# Finished epoch 11.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 21.706448021430084
# Average action magnitude: 0.9079107046127319
# ----------------------------------------------------------
# Finished epoch 12.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.99357278583846
# Average action magnitude: 0.9287164807319641
# ----------------------------------------------------------
# Finished epoch 13.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
# Average reward: 20.122515912218667
# Average action magnitude: 0.9272024035453796
# ----------------------------------------------------------
# Finished epoch 14.0. Running validation ...
# Validation completed:
# Number of episodes: 5
# Average episode length: 300.0
